# %%
import numpy as np
from astropy.io import fits
from scipy.optimize import curve_fit
import os
import glob
from pylab import *
from math import e
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.ndimage import rotate
import matplotlib.animation as animation
from IPython.display import HTML

import pandas as pd

# %%
notes = "early test"

#add notes here. 

#NOTE: GO TO CELL 27

# %%
#change to filenames and folder name
foldername_date = "20251120"
foldername = "pumpsoff"

#change to path
filepath = "/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/" + foldername_date + "_data/" + foldername
folderpath_date = "/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/" + foldername_date + "_data/" 
path1 = filepath + "/" + foldername +"_fits/*.fits"

print(path1)


#path1  = "/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/temp_fits/1-833-stability*11*.fits"
#path1 = "/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20250917_fits/*.fits"
#path1 = "/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/morning5237_0926_fits/*.fits"

fits_list = glob.glob(path1)
fits_list = np.sort(fits_list,kind='standardsort')

#fits_list = sorted(fits_list, key=lambda x: int(re.search(r'fanoff(\d+)', x).group(1)))


#sorted_list = sorted(fits_list, key=lambda x: int(re.search(r'stability(\d+)', x).group(1)))

#np.set_printoptions(threshold=np.inf)  # show entire array, no truncation


# only keep files that match "stability blah blah 123"
#fits_list = [f for f in fits_list if re.search(r'stability(\d+)', f)]

#sorted_list = sorted(fits_list, key=lambda x: int(re.search(r'stability(\d+)', x).group(1)))

for f in fits_list:
    print(f)

#print(fits_list)
#print(len(fits_list))


#print(fits_list[:5])   # first few
#print(fits_list[-5:])  # last few
# Out:
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/*.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0001 25-11-20 16-19-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0002 25-11-20 16-20-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0003 25-11-20 16-21-12.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0004 25-11-20 16-22-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0005 25-11-20 16-23-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0006 25-11-20 16-24-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0007 25-11-20 16-25-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0008 25-11-20 16-26-12.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0009 25-11-20 16-27-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0010 25-11-20 16-28-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0011 25-11-20 16-29-12.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0012 25-11-20 16-30-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0013 25-11-20 16-31-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0014 25-11-20 16-32-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0015 25-11-20 16-33-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0016 25-11-20 16-34-12.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0017 25-11-20 16-35-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0018 25-11-20 16-36-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0019 25-11-20 16-37-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0020 25-11-20 16-38-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0021 25-11-20 16-39-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0022 25-11-20 16-40-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0023 25-11-20 16-41-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0024 25-11-20 16-42-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0025 25-11-20 16-43-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0026 25-11-20 16-44-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0027 25-11-20 16-45-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0028 25-11-20 16-46-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0029 25-11-20 16-47-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0030 25-11-20 16-48-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0031 25-11-20 16-49-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0032 25-11-20 16-50-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0033 25-11-20 16-51-14.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0034 25-11-20 16-52-14.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0035 25-11-20 16-53-13.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0036 25-11-20 16-54-14.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0037 25-11-20 16-55-14.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0038 25-11-20 16-56-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0039 25-11-20 16-57-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0040 25-11-20 16-58-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0041 25-11-20 16-59-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0042 25-11-20 17-00-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0043 25-11-20 17-01-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0044 25-11-20 17-02-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0045 25-11-20 17-03-14.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0046 25-11-20 17-04-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0047 25-11-20 17-05-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0048 25-11-20 17-06-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0049 25-11-20 17-07-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0050 25-11-20 17-08-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0051 25-11-20 17-09-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0052 25-11-20 17-10-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0053 25-11-20 17-11-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0054 25-11-20 17-12-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0055 25-11-20 17-13-14.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0056 25-11-20 17-14-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0057 25-11-20 17-15-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0058 25-11-20 17-16-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0059 25-11-20 17-17-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0060 25-11-20 17-18-14.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0061 25-11-20 17-19-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0062 25-11-20 17-20-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0063 25-11-20 17-21-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0064 25-11-20 17-22-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0065 25-11-20 17-23-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0066 25-11-20 17-24-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0067 25-11-20 17-25-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0068 25-11-20 17-26-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0069 25-11-20 17-27-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0070 25-11-20 17-28-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0071 25-11-20 17-29-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0072 25-11-20 17-30-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0073 25-11-20 17-31-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0074 25-11-20 17-32-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0075 25-11-20 17-33-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0076 25-11-20 17-34-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0077 25-11-20 17-35-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0078 25-11-20 17-36-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0079 25-11-20 17-37-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0080 25-11-20 17-38-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0081 25-11-20 17-39-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0082 25-11-20 17-40-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0083 25-11-20 17-41-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0084 25-11-20 17-42-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0085 25-11-20 17-43-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0086 25-11-20 17-44-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0087 25-11-20 17-45-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0088 25-11-20 17-46-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0089 25-11-20 17-47-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0090 25-11-20 17-48-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0091 25-11-20 17-49-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0092 25-11-20 17-50-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0093 25-11-20 17-51-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0094 25-11-20 17-52-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0095 25-11-20 17-53-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0096 25-11-20 17-54-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0097 25-11-20 17-55-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0098 25-11-20 17-56-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0099 25-11-20 17-57-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0100 25-11-20 17-58-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0101 25-11-20 17-59-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0102 25-11-20 18-00-15.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0103 25-11-20 18-01-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0104 25-11-20 18-02-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0105 25-11-20 18-03-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0106 25-11-20 18-04-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0107 25-11-20 18-05-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0108 25-11-20 18-06-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0109 25-11-20 18-07-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0110 25-11-20 18-08-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0111 25-11-20 18-09-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0112 25-11-20 18-10-17.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0113 25-11-20 18-11-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0114 25-11-20 18-12-17.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0115 25-11-20 18-13-17.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0116 25-11-20 18-14-17.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0117 25-11-20 18-15-17.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0118 25-11-20 18-16-17.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0119 25-11-20 18-17-16.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0120 25-11-20 18-18-17.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0121 25-11-20 18-19-17.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0122 25-11-20 18-20-17.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0123 25-11-20 18-21-17.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0124 25-11-20 18-22-17.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0125 25-11-20 18-23-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0126 25-11-20 18-24-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0127 25-11-20 18-25-17.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0128 25-11-20 18-26-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0129 25-11-20 18-27-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0130 25-11-20 18-28-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0131 25-11-20 18-29-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0132 25-11-20 18-30-17.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0133 25-11-20 18-31-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0134 25-11-20 18-32-17.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0135 25-11-20 18-33-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0136 25-11-20 18-34-17.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0137 25-11-20 18-35-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0138 25-11-20 18-36-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0139 25-11-20 18-37-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0140 25-11-20 18-38-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0141 25-11-20 18-39-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0142 25-11-20 18-40-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0143 25-11-20 18-41-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0144 25-11-20 18-42-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0145 25-11-20 18-43-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0146 25-11-20 18-44-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0147 25-11-20 18-45-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0148 25-11-20 18-46-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0149 25-11-20 18-47-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0150 25-11-20 18-48-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0151 25-11-20 18-49-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0152 25-11-20 18-50-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0153 25-11-20 18-51-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0154 25-11-20 18-52-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0155 25-11-20 18-53-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0156 25-11-20 18-54-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0157 25-11-20 18-55-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0158 25-11-20 18-56-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0159 25-11-20 18-57-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0160 25-11-20 18-58-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0161 25-11-20 18-59-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0162 25-11-20 19-00-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0163 25-11-20 19-01-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0164 25-11-20 19-02-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0165 25-11-20 19-03-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0166 25-11-20 19-04-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0167 25-11-20 19-05-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0168 25-11-20 19-06-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0169 25-11-20 19-07-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0170 25-11-20 19-08-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0171 25-11-20 19-09-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0172 25-11-20 19-10-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0173 25-11-20 19-11-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0174 25-11-20 19-12-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0175 25-11-20 19-13-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0176 25-11-20 19-14-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0177 25-11-20 19-15-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0178 25-11-20 19-16-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0179 25-11-20 19-17-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0180 25-11-20 19-18-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0181 25-11-20 19-19-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0182 25-11-20 19-20-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0183 25-11-20 19-21-18.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0184 25-11-20 19-22-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0185 25-11-20 19-23-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0186 25-11-20 19-24-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0187 25-11-20 19-25-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0188 25-11-20 19-26-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0189 25-11-20 19-27-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0190 25-11-20 19-28-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0191 25-11-20 19-29-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0192 25-11-20 19-30-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0193 25-11-20 19-31-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0194 25-11-20 19-32-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0195 25-11-20 19-33-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0196 25-11-20 19-34-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0197 25-11-20 19-35-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0198 25-11-20 19-36-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0199 25-11-20 19-37-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0200 25-11-20 19-38-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0201 25-11-20 19-39-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0202 25-11-20 19-40-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0203 25-11-20 19-41-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0204 25-11-20 19-42-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0205 25-11-20 19-43-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0206 25-11-20 19-44-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0207 25-11-20 19-45-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0208 25-11-20 19-46-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0209 25-11-20 19-47-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0210 25-11-20 19-48-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0211 25-11-20 19-49-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0212 25-11-20 19-50-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0213 25-11-20 19-51-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0214 25-11-20 19-52-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0215 25-11-20 19-53-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0216 25-11-20 19-54-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0217 25-11-20 19-55-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0218 25-11-20 19-56-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0219 25-11-20 19-57-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0220 25-11-20 19-58-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0221 25-11-20 19-59-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0222 25-11-20 20-00-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0223 25-11-20 20-01-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0224 25-11-20 20-02-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0225 25-11-20 20-03-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0226 25-11-20 20-04-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0227 25-11-20 20-05-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0228 25-11-20 20-06-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0229 25-11-20 20-07-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0230 25-11-20 20-08-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0231 25-11-20 20-09-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0232 25-11-20 20-10-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0233 25-11-20 20-11-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0234 25-11-20 20-12-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0235 25-11-20 20-13-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0236 25-11-20 20-14-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0237 25-11-20 20-15-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0238 25-11-20 20-16-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0239 25-11-20 20-17-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0240 25-11-20 20-18-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0241 25-11-20 20-19-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0242 25-11-20 20-20-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0243 25-11-20 20-21-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0244 25-11-20 20-22-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0245 25-11-20 20-23-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0246 25-11-20 20-24-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0247 25-11-20 20-25-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0248 25-11-20 20-26-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0249 25-11-20 20-27-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0250 25-11-20 20-28-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0251 25-11-20 20-29-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0252 25-11-20 20-30-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0253 25-11-20 20-31-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0254 25-11-20 20-32-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0255 25-11-20 20-33-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0256 25-11-20 20-34-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0257 25-11-20 20-35-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0258 25-11-20 20-36-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0259 25-11-20 20-37-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0260 25-11-20 20-38-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0261 25-11-20 20-39-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0262 25-11-20 20-40-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0263 25-11-20 20-41-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0264 25-11-20 20-42-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0265 25-11-20 20-43-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0266 25-11-20 20-44-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0267 25-11-20 20-45-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0268 25-11-20 20-46-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0269 25-11-20 20-47-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0270 25-11-20 20-48-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0271 25-11-20 20-49-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0272 25-11-20 20-50-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0273 25-11-20 20-51-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0274 25-11-20 20-52-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0275 25-11-20 20-53-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0276 25-11-20 20-54-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0277 25-11-20 20-55-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0278 25-11-20 20-56-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0279 25-11-20 20-57-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0280 25-11-20 20-58-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0281 25-11-20 20-59-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0282 25-11-20 21-00-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0283 25-11-20 21-01-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0284 25-11-20 21-02-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0285 25-11-20 21-03-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0286 25-11-20 21-04-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0287 25-11-20 21-05-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0288 25-11-20 21-06-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0289 25-11-20 21-07-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0290 25-11-20 21-08-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0291 25-11-20 21-09-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0292 25-11-20 21-10-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0293 25-11-20 21-11-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0294 25-11-20 21-12-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0295 25-11-20 21-13-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0296 25-11-20 21-14-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0297 25-11-20 21-15-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0298 25-11-20 21-16-19.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0299 25-11-20 21-17-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0300 25-11-20 21-18-20.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0301 25-11-20 21-19-21.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0302 25-11-20 21-20-21.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0303 25-11-20 21-21-21.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0304 25-11-20 21-22-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0305 25-11-20 21-23-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0306 25-11-20 21-24-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0307 25-11-20 21-25-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0308 25-11-20 21-26-21.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0309 25-11-20 21-27-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0310 25-11-20 21-28-21.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0311 25-11-20 21-29-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0312 25-11-20 21-30-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0313 25-11-20 21-31-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0314 25-11-20 21-32-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0315 25-11-20 21-33-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0316 25-11-20 21-34-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0317 25-11-20 21-35-21.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0318 25-11-20 21-36-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0319 25-11-20 21-37-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0320 25-11-20 21-38-21.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0321 25-11-20 21-39-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0322 25-11-20 21-40-21.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0323 25-11-20 21-41-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0324 25-11-20 21-42-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0325 25-11-20 21-43-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0326 25-11-20 21-44-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0327 25-11-20 21-45-21.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0328 25-11-20 21-46-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0329 25-11-20 21-47-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0330 25-11-20 21-48-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0331 25-11-20 21-49-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0332 25-11-20 21-50-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0333 25-11-20 21-51-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0334 25-11-20 21-52-21.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0335 25-11-20 21-53-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0336 25-11-20 21-54-21.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0337 25-11-20 21-55-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0338 25-11-20 21-56-21.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0339 25-11-20 21-57-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0340 25-11-20 21-58-21.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0341 25-11-20 21-59-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0342 25-11-20 22-00-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0343 25-11-20 22-01-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0344 25-11-20 22-02-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0345 25-11-20 22-03-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0346 25-11-20 22-04-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0347 25-11-20 22-05-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0348 25-11-20 22-06-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0349 25-11-20 22-07-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0350 25-11-20 22-08-21.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0351 25-11-20 22-09-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0352 25-11-20 22-10-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0353 25-11-20 22-11-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0354 25-11-20 22-12-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0355 25-11-20 22-13-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0356 25-11-20 22-14-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0357 25-11-20 22-15-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0358 25-11-20 22-16-21.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0359 25-11-20 22-17-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0360 25-11-20 22-18-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0361 25-11-20 22-19-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0362 25-11-20 22-20-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0363 25-11-20 22-21-21.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0364 25-11-20 22-22-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0365 25-11-20 22-23-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0366 25-11-20 22-24-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0367 25-11-20 22-25-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0368 25-11-20 22-26-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0369 25-11-20 22-27-23.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0370 25-11-20 22-28-23.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0371 25-11-20 22-29-23.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0372 25-11-20 22-30-23.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0373 25-11-20 22-31-23.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0374 25-11-20 22-32-23.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0375 25-11-20 22-33-23.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0376 25-11-20 22-34-23.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0377 25-11-20 22-35-23.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0378 25-11-20 22-36-23.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0379 25-11-20 22-37-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0380 25-11-20 22-38-23.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0381 25-11-20 22-39-22.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0382 25-11-20 22-40-23.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0383 25-11-20 22-41-23.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0384 25-11-20 22-42-23.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0385 25-11-20 22-43-23.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff0386 25-11-20 22-44-23.fits
# ...
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5472 25-11-24 11-31-52.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5473 25-11-24 11-32-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5474 25-11-24 11-33-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5475 25-11-24 11-34-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5476 25-11-24 11-35-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5477 25-11-24 11-36-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5478 25-11-24 11-37-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5479 25-11-24 11-38-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5480 25-11-24 11-39-52.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5481 25-11-24 11-40-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5482 25-11-24 11-41-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5483 25-11-24 11-42-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5484 25-11-24 11-43-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5485 25-11-24 11-44-52.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5486 25-11-24 11-45-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5487 25-11-24 11-46-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5488 25-11-24 11-47-52.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5489 25-11-24 11-48-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5490 25-11-24 11-49-52.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5491 25-11-24 11-50-52.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5492 25-11-24 11-51-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5493 25-11-24 11-52-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5494 25-11-24 11-53-52.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5495 25-11-24 11-54-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5496 25-11-24 11-55-52.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5497 25-11-24 11-56-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5498 25-11-24 11-57-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5499 25-11-24 11-58-52.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5500 25-11-24 11-59-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5501 25-11-24 12-00-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5502 25-11-24 12-01-52.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5503 25-11-24 12-02-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5504 25-11-24 12-03-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5505 25-11-24 12-04-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5506 25-11-24 12-05-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5507 25-11-24 12-06-52.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5508 25-11-24 12-07-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5509 25-11-24 12-08-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5510 25-11-24 12-09-52.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5511 25-11-24 12-10-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5512 25-11-24 12-11-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5513 25-11-24 12-12-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5514 25-11-24 12-13-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5515 25-11-24 12-14-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5516 25-11-24 12-15-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5517 25-11-24 12-16-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5518 25-11-24 12-17-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5519 25-11-24 12-18-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5520 25-11-24 12-19-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5521 25-11-24 12-20-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5522 25-11-24 12-21-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5523 25-11-24 12-22-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5524 25-11-24 12-23-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5525 25-11-24 12-24-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5526 25-11-24 12-25-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5527 25-11-24 12-26-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5528 25-11-24 12-27-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5529 25-11-24 12-28-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5530 25-11-24 12-29-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5531 25-11-24 12-30-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5532 25-11-24 12-31-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5533 25-11-24 12-32-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5534 25-11-24 12-33-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5535 25-11-24 12-34-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5536 25-11-24 12-35-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5537 25-11-24 12-36-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5538 25-11-24 12-37-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5539 25-11-24 12-38-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5540 25-11-24 12-39-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5541 25-11-24 12-40-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5542 25-11-24 12-41-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5543 25-11-24 12-42-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5544 25-11-24 12-43-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5545 25-11-24 12-44-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5546 25-11-24 12-45-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5547 25-11-24 12-46-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5548 25-11-24 12-47-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5549 25-11-24 12-48-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5550 25-11-24 12-49-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5551 25-11-24 12-50-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5552 25-11-24 12-51-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5553 25-11-24 12-52-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5554 25-11-24 12-53-53.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5555 25-11-24 12-54-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5556 25-11-24 12-55-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5557 25-11-24 12-56-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5558 25-11-24 12-57-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5559 25-11-24 12-58-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5560 25-11-24 12-59-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5561 25-11-24 13-00-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5562 25-11-24 13-01-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5563 25-11-24 13-02-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5564 25-11-24 13-03-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5565 25-11-24 13-04-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5566 25-11-24 13-05-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5567 25-11-24 13-06-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5568 25-11-24 13-07-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5569 25-11-24 13-08-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5570 25-11-24 13-09-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5571 25-11-24 13-10-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5572 25-11-24 13-11-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5573 25-11-24 13-12-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5574 25-11-24 13-13-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5575 25-11-24 13-14-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5576 25-11-24 13-15-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5577 25-11-24 13-16-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5578 25-11-24 13-17-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5579 25-11-24 13-18-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5580 25-11-24 13-19-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5581 25-11-24 13-20-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5582 25-11-24 13-21-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5583 25-11-24 13-22-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5584 25-11-24 13-23-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5585 25-11-24 13-24-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5586 25-11-24 13-25-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5587 25-11-24 13-26-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5588 25-11-24 13-27-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5589 25-11-24 13-28-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5590 25-11-24 13-29-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5591 25-11-24 13-30-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5592 25-11-24 13-31-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5593 25-11-24 13-32-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5594 25-11-24 13-33-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5595 25-11-24 13-34-54.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5596 25-11-24 13-35-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5597 25-11-24 13-36-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5598 25-11-24 13-37-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5599 25-11-24 13-38-55.fits
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff_fits/pumpsoff5600 25-11-24 13-39-54.fits

# %%
'''
def openfits(path):
    
    hdu = fits.open(path)
    data = hdu[0].data    #data
    hdr = hdu[0].header    # headers
    
    #image_data = fits.getdata(path, ext=0)
    #image_data = np.flip(np.transpose(image_data), axis=1) #flip data by 90 degrees
    #image_data = np.flip(image_data, axis=(0, 1)) #flip data by 180 degrees
    
    #data = np.flip(np.transpose(data), axis=1) #flip data by 90 degrees
    data = np.flip(data, axis=(0, 1)) #flip data by 180 degrees
    
    image_data = data
    
    shape = image_data.shape #shape
    
    return hdu, data, hdr, image_data, shape
    
    '''

#use "with" to close file 

def openfits(path):
    with fits.open(path) as hdu:
        data = hdu[0].data   
        hdr  = hdu[0].header  # header
        
        # transform data
        data = np.flip(data, axis=(0, 1)) 
        
        image_data = data.copy()  
        shape = image_data.shape
    
    return None, image_data, hdr, image_data, shape

# %%
hdu = []
data = []
hdr = []
image_data = []
shape = []

for fits_file in fits_list:
    hdu_temp, data_temp, hdr_temp, image_data_temp, shape_temp = openfits(fits_file)
    
    #data_temp = data_temp[0, :, :]
    
    hdu.append(hdu_temp)
    data.append(data_temp)
    hdr.append(hdr_temp)
    image_data.append(image_data_temp)
    shape.append(shape_temp)

# %%
plt.figure(figsize=(10,10))
plt.imshow(data[0], cmap='viridis', vmin = 0, vmax = 100)
#plt.title("title", fontsize=20)
#plt.plot(sum_dat)
#cbar = plt.colorbar()
#cbar.set_label('Ec', fontsize=15)
#plt.colorbar()

# %%
fig, ax = plt.subplots(figsize=(10,10))
im = ax.imshow(data[0], cmap='viridis', vmin=0, vmax=100)

def update(frame):
    im.set_array(data[frame])
    return [im]


#if want inline 

#ani = animation.FuncAnimation(fig, update, frames=len(data), interval=200, blit=True)
#HTML(ani.to_jshtml())

# %%
print(len(data[0][0]))
print(len(data[0]))
print(data[0].shape)
# Out:
# 2560
# 1920
# (1920, 2560)

# %%
profiles_x = []
profiles_y = []

for img in data:
    #collapse along y (rows)
    profiles_x.append(np.sum(img, axis=0))

    #collapse along x (columns)
    profiles_y.append(np.sum(img, axis=1))

profiles_x = np.array(profiles_x) 
profiles_y = np.array(profiles_y)

# %%
filename = os.path.basename(filepath)

#the txt file that was generated in bmp_to_fits 
log_path = filepath + "/" + foldername + ".txt"

print(log_path)
print(folderpath_date)

print(folderpath_date + foldername + "/" + foldername)
# Out:
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff.txt
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251120_data/pumpsoff/pumpsoff

# %%
#get times from .txt path and put it in the video 

df_times = pd.read_csv(
    log_path,
    sep=r'\t+',              #split by tabs
    engine='python',
    skiprows=2,              #skip the first two lines in header
    names=["Filename", "Creation Date"]
)

#nno more blanke space in case there's blank space 
df_times["Filename"] = df_times["Filename"].str.strip()
df_times["Creation Date"] = df_times["Creation Date"].str.strip()

# %%
#this plot/function takes approximately 10000 years to run heads up 
#comment out if you can live without a video 

fig = plt.figure(figsize=(10, 8))
gs = fig.add_gridspec(2, 2, width_ratios=[4,1], height_ratios=[1,4], wspace=0.0, hspace=0.0)

ax_img = fig.add_subplot(gs[1,0])
ax_x   = fig.add_subplot(gs[0,0], sharex=ax_img)
ax_y   = fig.add_subplot(gs[1,1], sharey=ax_img)
fig.add_subplot(gs[0,1]).axis("off")

im = ax_img.imshow(data[0], cmap="viridis", origin="lower", vmin=0, vmax=100, aspect="auto")

profile_x = np.sum(data[0], axis=0)
profile_y = np.sum(data[0], axis=1)

line_x, = ax_x.plot(np.arange(data[0].shape[1]), profile_x)
line_y, = ax_y.plot(profile_y, np.arange(data[0].shape[0]))

ax_x.set_xlim(ax_img.get_xlim())
ax_y.set_ylim(ax_img.get_ylim())

ax_x.tick_params(labelbottom=False)
ax_y.tick_params(labelleft=False)
ax_x.set_ylabel("counts")
ax_y.set_xlabel("counts")
ax_x.grid()
ax_y.grid()

max_x = max(np.sum(img, axis=0).max() for img in data)
max_y = max(np.sum(img, axis=1).max() for img in data)
min_x = max(np.sum(img, axis=0).min() for img in data)
min_y = max(np.sum(img, axis=1).min() for img in data)

ax_x.set_ylim(min_x - 200, max_x - 200)
ax_y.set_xlim(min_y - 200, max_y)


timestamp_text = ax_img.text(
    0.02, 0.98, "", 
    transform=ax_img.transAxes, 
    color="white", 
    fontsize=12, 
    verticalalignment="top",
    bbox=dict(facecolor="black", alpha=0.5, edgecolor="none", pad=3)
)


def update(frame):
    img = data[frame]
    im.set_array(img)

    profile_x = np.sum(img, axis=0)
    profile_y = np.sum(img, axis=1)
    line_x.set_ydata(profile_x)
    line_y.set_xdata(profile_y)


    if frame < len(df_times):
        timestamp = df_times.iloc[frame]["Creation Date"]
        timestamp_text.set_text(f"{timestamp}")
    else:
        timestamp_text.set_text("")

    return [im, line_x, line_y, timestamp_text]

ani = animation.FuncAnimation(fig, update, frames=len(data), interval=200, blit=True)
HTML(ani.to_jshtml())

#save video (comment out if you do not want it)
Writer = animation.writers['ffmpeg']
writer = Writer(fps=20, metadata=dict(artist='Me'), bitrate=1800)
ani.save(folderpath_date + foldername + "/" + foldername + ".mp4", writer=writer)
# Out:
# Animation size has reached 21116665 bytes, exceeding the limit of 20971520.0. If you're sure you want a larger animation embedded, set the animation.embed_limit rc parameter to a larger value (in MB). This and further frames will be dropped.

# %%
# example fit for just first frame


def gaussian(x, amp, mu, sigma, offset):
    return amp * np.exp(-0.5 * ((x - mu)/sigma)**2) + offset


img = data[0]

profile_x = np.sum(img, axis=0)
profile_y = np.sum(img, axis=1)

x_vals = np.arange(profile_x.size)
p0_x = [profile_x.max(), profile_x.argmax(), 5, np.median(profile_x)]  # initial guess
popt_x, pcov_x = curve_fit(gaussian, x_vals, profile_x, p0=p0_x)

y_vals = np.arange(profile_y.size)
p0_y = [profile_y.max(), profile_y.argmax(), 5, np.median(profile_y)]
popt_y, pcov_y = curve_fit(gaussian, y_vals, profile_y, p0=p0_y)

# popt_x = [amp, mu, sigma, offset] for x-profile
# popt_y = [amp, mu, sigma, offset] for y-profile

# Generate smooth fit curves
x_fit = gaussian(x_vals, *popt_x)
y_fit = gaussian(y_vals, *popt_y)

print("X fit:", popt_x)
print("Y fit:", popt_y)
# Out:
# X fit: [24154.8466439    995.8168607    187.84156758 27324.22407514]
# Y fit: [26099.78488791  1455.84616621   167.79071928 36654.90811103]

# %%
plot(np.arange(data[0].shape[1]), profile_x) 
plot(x_vals, x_fit, 'r--', label="Gaussian fit")

# %%
plot(np.arange(data[0].shape[0]), profile_y) 
plot(y_vals, y_fit, 'r--', label="Gaussian fit")

# %%
#do it for everythign

def gaussian(x, amp, mu, sigma, offset):
    return amp * np.exp(-0.5 * ((x - mu)/sigma)**2) + offset

#initialize
amps_x, mus_x, sigmas_x, offsets_x = [], [], [], []
amps_y, mus_y, sigmas_y, offsets_y = [], [], [], []

for img in data:
    profile_x = np.sum(img, axis=0)
    profile_y = np.sum(img, axis=1)

    #fit x
    x_vals = np.arange(profile_x.size)
    p0_x = [profile_x.max(), profile_x.argmax(), 5, np.median(profile_x)]
    try:
        popt_x, _ = curve_fit(gaussian, x_vals, profile_x, p0=p0_x)
    except RuntimeError:
        popt_x = [np.nan]*4

    amps_x.append(popt_x[0])
    mus_x.append(popt_x[1])
    sigmas_x.append(popt_x[2])
    offsets_x.append(popt_x[3])

    #fit y
    y_vals = np.arange(profile_y.size)
    p0_y = [profile_y.max(), profile_y.argmax(), 5, np.median(profile_y)]
    try:
        popt_y, _ = curve_fit(gaussian, y_vals, profile_y, p0=p0_y)
    except RuntimeError:
        popt_y = [np.nan]*4

    amps_y.append(popt_y[0])
    mus_y.append(popt_y[1])
    sigmas_y.append(popt_y[2])
    offsets_y.append(popt_y[3])

#to np.array
amps_x = np.array(amps_x)
mus_x = np.array(mus_x)
sigmas_x = np.array(sigmas_x)
offsets_x = np.array(offsets_x)

amps_y = np.array(amps_y)
mus_y = np.array(mus_y)
sigmas_y = np.array(sigmas_y)
offsets_y = np.array(offsets_y)

# %%
#need to add cut to data for bad fits and NANs 

def filter_fits(amps_x, mus_x, sigmas_x, offsets_x,
                amps_y, mus_y, sigmas_y, offsets_y,
                fwhm_min, fwhm_max):
    
    fwhm_x = 2.355 * sigmas_x
    fwhm_y = 2.355 * sigmas_y

    #mask for NANs & infs
    finite_mask = (
        np.isfinite(amps_x) & np.isfinite(mus_x) & np.isfinite(sigmas_x) & np.isfinite(offsets_x) &
        np.isfinite(amps_y) & np.isfinite(mus_y) & np.isfinite(sigmas_y) & np.isfinite(offsets_y)
    )

    #mask for FWHM
    fwhm_mask = (
        (fwhm_x > fwhm_min) & (fwhm_x < fwhm_max) &
        (fwhm_y > fwhm_min) & (fwhm_y < fwhm_max)
    )

    #both 
    mask = finite_mask & fwhm_mask

    return (amps_x[mask], mus_x[mask], sigmas_x[mask], offsets_x[mask],
            amps_y[mask], mus_y[mask], sigmas_y[mask], offsets_y[mask],
            fwhm_x[mask], fwhm_y[mask], mask)

# %%
filtered = filter_fits(amps_x, mus_x, sigmas_x, offsets_x,
                       amps_y, mus_y, sigmas_y, offsets_y,
                       fwhm_min=1, fwhm_max=1000)

filtered
# Out:
# (array([24154.8466439 , 24147.98708907, 24142.61010472, ...,
#         24099.45921828, 24140.53900295, 24125.73119639]),
#  array([995.8168607 , 995.00965181, 997.64241078, ..., 993.09884242,
#         995.12838638, 995.12772696]),
#  array([187.84156758, 187.87832742, 187.71936148, ..., 186.29452481,
#         186.13475876, 186.22878043]),
#  array([27324.22407514, 27324.95132479, 27317.05142204, ...,
#         27274.00742191, 27273.26036848, 27330.41818368]),
#  array([26099.78488791, 26080.18775202, 26092.9023812 , ...,
#         26077.90754805, 26052.2131026 , 26082.54899991]),
#  array([1455.84616621, 1452.73390038, 1451.14160602, ..., 1453.1887211 ,
#         1449.67056183, 1452.67743741]),
#  array([167.79071928, 168.00697043, 167.74492961, ..., 166.65903925,
#         166.77981119, 166.68447621]),
#  array([36654.90811103, 36651.55782014, 36640.16407467, ...,
#         36567.24687369, 36571.8474507 , 36644.7901232 ]),
#  array([442.36689166, 442.45346109, 442.07909628, ..., 438.72360592,
#         438.34735689, 438.5687779 ]),
#  array([395.14714391, 395.65641536, 395.03930922, ..., 392.48203743,
#         392.76645536, 392.54194148]),
#  array([ True,  True,  True, ...,  True,  True,  True]))

# %%
(amps_x_f, mus_x_f, sigmas_x_f, offsets_x_f,
 amps_y_f, mus_y_f, sigmas_y_f, offsets_y_f,
 fwhm_x_f, fwhm_y_f, mask) = filtered

print(len(amps_x_f))
print(len(fwhm_y_f))
# Out:
# 5600
# 5600

# %%
#recenter relative to first frame
mu_x_rel = mus_x_f - mus_x_f[0]
mu_y_rel = mus_y_f - mus_y_f[0]

frames = np.arange(len(mu_x_rel))

print(mu_x_rel)
print(mu_y_rel)
# Out:
# [ 0.         -0.80720889  1.82555008 ... -2.71801828 -0.68847432
#  -0.68913375]
# [ 0.         -3.11226584 -4.7045602  ... -2.65744511 -6.17560438
#  -3.16872881]

# %%
fig, axs = plt.subplots(2, 1, figsize=(8, 8), sharex=True)

axs[0].plot(frames, mu_x_rel, color='blue')
axs[0].set_ylabel("X centroid shift (pixels)")
#axs[0].set_title("X centroid over time")
axs[0].grid(True)
linex = axs[0].plot(
    [frames[0], frames[-1]],
    [mu_x_rel[0], mu_x_rel[-1]],
    color='red'
)[0]   

#slope
slopex = (mu_x_rel[-1] - mu_x_rel[0]) / (frames[-1] - frames[0])


axs[0].legend([linex], [f"Slope = {slopex:.4f} px/frame"])


axs[1].plot(frames, mu_y_rel, color='green')
axs[1].set_xlabel("Frame")
axs[1].set_ylabel("Y centroid shift (pixels)")
#axs[1].set_title("Y centroid over time")
axs[1].grid(True)
liney = axs[1].plot(
    [frames[0], frames[-1]],
    [mu_y_rel[0], mu_y_rel[-1]],
    color='red', alpha=0.5
)[0]   #

#slope
slopey = (mu_y_rel[-1] - mu_y_rel[0]) / (frames[-1] - frames[0])


axs[1].legend([liney], [f"Slope = {slopey:.4f} px/frame"])

plt.tight_layout()
plt.show()

fig.savefig(folderpath_date + foldername + "/" + foldername + "_position", dpi=300, bbox_inches="tight")

# %%
#FWHM
FWHM_factor = 2 * np.sqrt(2 * np.log(2))  # ~2.35482
FWHM_x = sigmas_x_f * FWHM_factor
FWHM_y = sigmas_y_f * FWHM_factor

frames = np.arange(len(FWHM_x))

print(FWHM_x)
print(FWHM_y)
# Out:
# [442.33308863 442.41965145 442.04531524 ... 438.6900813  438.31386101
#  438.53526511]
# [395.11694914 395.62618167 395.00912269 ... 392.45204631 392.73644251
#  392.51194578]

# %%
fig, axs = plt.subplots(2, 1, figsize=(8, 8), sharex=True)

#x FWHM
axs[0].plot(frames, FWHM_x, color='blue')
axs[0].set_ylabel("FWHM X (pixels)")
#axs[0].set_title("X FWHM over frames")
axs[0].grid(True)
axs[0].grid(True)
linexfwhm = axs[0].plot(
    [frames[0], frames[-1]],
    [FWHM_x[0], FWHM_x[-1]],
    color='red', alpha=0.5
)[0]   

# slope
slopexfwhm = (FWHM_x[-1] - FWHM_x[0]) / (frames[-1] - frames[0])

axs[0].legend([linexfwhm], [f"Slope = {slopexfwhm:.4f} px/frame"])


#y FWHM
axs[1].plot(frames, FWHM_y, color='green')
axs[1].set_xlabel("Frame")
axs[1].set_ylabel("FWHM Y (pixels)")
#axs[1].set_title("Y FWHM over frames")
axs[1].grid(True)
lineyfwhm = axs[1].plot(
    [frames[0], frames[-1]],
    [FWHM_y[0], FWHM_y[-1]],
    color='red', alpha=0.5
)[0]  

#slope
slopeyfwhm = (FWHM_y[-1] - FWHM_y[0]) / (frames[-1] - frames[0])

axs[1].legend([lineyfwhm], [f"Slope = {slopeyfwhm:.4f} px/frame"])


plt.tight_layout()
plt.show()


fig.savefig(folderpath_date + foldername + "/" + foldername + "_FWHM", dpi=300, bbox_inches="tight")

# %%
print(np.mean(mu_x_rel))
print(np.mean(mu_y_rel))
print(np.std(mu_x_rel))
print(np.std(mu_y_rel))
# Out:
# 3.9023484178351784
# -17.41995355429897
# 11.34707930208846
# 14.437846553024512

# %%
print(np.mean(FWHM_x))
print(np.mean(FWHM_y))
print(np.std(FWHM_x))
print(np.std(FWHM_y))
# Out:
# 435.5348499704827
# 390.75316133339754
# 5.764318960893136
# 4.054880012094375

# %%
def compute_fft(signal, dt):
    N = len(signal)
    fft_vals = np.fft.fft(signal - np.mean(signal))  # remove DC offset
    freqs = np.fft.fftfreq(N, d=dt)
    mask = freqs > 0
    return freqs[mask], np.abs(fft_vals[mask])**2


####################################################
#############
##CHANGE THIS DEPENDING ON FRAME RATE OF TEST
## comment out either top two or bottom two 
#############

#frame_rate = 52.37   
#dt = 1.0 / frame_rate

frame_rate = 1/60       
dt = 60.0               


####################################################

#ffts
freqs_x, power_mu_x   = compute_fft(mu_x_rel, dt)
freqs_y, power_mu_y   = compute_fft(mu_y_rel, dt)
freqs_fx, power_fwhm_x = compute_fft(FWHM_x, dt)
freqs_fy, power_fwhm_y = compute_fft(FWHM_y, dt)


fig, axs = plt.subplots(2, 2, figsize=(12, 8))

axs[0,0].plot(freqs_x, power_mu_x)
axs[0,0].set_title("FFT of centroid (relative x)")
axs[0,0].set_xlabel("Frequency [Hz]")
axs[0,0].set_ylabel("Power")

axs[0,1].plot(freqs_y, power_mu_y)
axs[0,1].set_title("FFT of centroid (relative y)")
axs[0,1].set_xlabel("Frequency [Hz]")
axs[0,1].set_ylabel("Power")

axs[1,0].plot(freqs_fx, power_fwhm_x)
axs[1,0].set_title("FFT of FWHM (x)")
axs[1,0].set_xlabel("Frequency [Hz]")
axs[1,0].set_ylabel("Power")

axs[1,1].plot(freqs_fy, power_fwhm_y)
axs[1,1].set_title("FFT of FWHM (y))")
axs[1,1].set_xlabel("Frequency [Hz]")
axs[1,1].set_ylabel("Power")

plt.tight_layout()
plt.show()


fig.savefig(folderpath_date + foldername + "/" + foldername + "_FFT", dpi=300, bbox_inches="tight")

# %%
filename = os.path.basename(filepath)
num_data = len(fits_list)
    
creation_date_start = str(fits_list[0][-22:-5])
creation_date_stop = str(fits_list[-1][-22:-5])

# %%
#put data into shared csv file
#comment out if you don't want it 

csv_path = "/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/collimated_beam_entry.xlsx"

df = pd.read_excel(csv_path, engine='openpyxl')

new_row = {
    'filename': filename,
    'number of frames': num_data,
    'start time': creation_date_start,
    'stop time': creation_date_stop,
    'notes': notes,
    'frame rate': frame_rate,
    'x position': np.mean(mu_x_rel*0.15),
    'x position std': np.std(mu_x_rel*0.15),
    'y position': np.mean(mu_y_rel*0.15),
    'y position std': np.std(mu_y_rel*0.15),
    'FWHM x': np.mean(FWHM_x*0.15),
    'FWHM x std': np.std(FWHM_x*0.15),
    'FWHM y': np.mean(FWHM_y*0.15),
    'FWHM y std': np.std(FWHM_y*0.15)
}


df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
df.to_excel(csv_path, index=False, engine='openpyxl')
